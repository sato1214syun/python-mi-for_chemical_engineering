# %% [markdown]
# ### Using Boruta on the Madalon Data Set
#
# この例では、Borutaを使ってMadelonデータセット内の関連する特徴量をすべて特定する方法を示します。MadelonはNIPS2003で使用された人工データセットであり、[Boruta論文](https://www.jstatsoft.org/article/view/v036i11/v36i11.pdf)でも引用されています。
#
# このデータセットは2000件の観測値と500個の特徴量を持っています。Borutaを用いて、分類タスクに関連する特徴量を特定します。

# %%
import polars as pl
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier

# %%
def load_data(train_data_url: str, train_label_url: str) -> pl.DataFrame:  # noqa: D103
    x_data = pl.read_csv(train_data_url, separator=" ", has_header=False).select(
        pl.nth(range(499))
    )
    y_data = pl.read_csv(train_label_url, separator=" ", has_header=False).rename(
        {"column_1": "target"}
    )
    mapping_val = {f"column_{i + 1}": f"{i}" for i in range(x_data.width)}
    return y_data.hstack(x_data).rename(mapping_val)

# %%
# URLS for dataset via UCI
train_data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_train.data"
train_label_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_train.labels"

data = load_data(train_data_url, train_label_url)
data.head()
# Out:
# shape: (5, 500)
# ┌────────┬─────┬─────┬─────┬───┬─────┬─────┬─────┬─────┐
# │ target ┆ 0   ┆ 1   ┆ 2   ┆ … ┆ 495 ┆ 496 ┆ 497 ┆ 498 │
# │ ---    ┆ --- ┆ --- ┆ --- ┆   ┆ --- ┆ --- ┆ --- ┆ --- │
# │ i64    ┆ i64 ┆ i64 ┆ i64 ┆   ┆ i64 ┆ i64 ┆ i64 ┆ i64 │
# ╞════════╪═════╪═════╪═════╪═══╪═════╪═════╪═════╪═════╡
# │ -1     ┆ 485 ┆ 477 ┆ 537 ┆ … ┆ 485 ┆ 481 ┆ 479 ┆ 475 │
# │ -1     ┆ 483 ┆ 458 ┆ 460 ┆ … ┆ 486 ┆ 483 ┆ 492 ┆ 510 │
# │ -1     ┆ 487 ┆ 542 ┆ 499 ┆ … ┆ 501 ┆ 480 ┆ 489 ┆ 499 │
# │ 1      ┆ 480 ┆ 491 ┆ 510 ┆ … ┆ 469 ┆ 475 ┆ 482 ┆ 494 │
# │ 1      ┆ 484 ┆ 502 ┆ 528 ┆ … ┆ 508 ┆ 481 ┆ 504 ┆ 495 │
# └────────┴─────┴─────┴─────┴───┴─────┴─────┴─────┴─────┘

# %%
y = data.get_column("target")
x = data.drop(y.name)

# %% [markdown]
# Borutaはscikit-learnのAPIに準拠しており、Pipeline内でも単独でも利用できます。ここでは単独での利用方法を説明します。
#
# まず、Borutaが利用するestimatorをインスタンス化します。次に、Borutaオブジェクトをインスタンス化します。

# %%
rf = RandomForestClassifier(n_jobs=-1, class_weight=None, max_depth=7, random_state=0)
# Define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators="auto", verbose=2, random_state=0)

# %% [markdown]
# 一度オブジェクトを作成すれば、このオブジェクトを使ってデータセット内の関連する特徴量を特定できます。

# %%
feat_selector.fit(x.to_numpy(), y.to_numpy())
# Out:
# 0.03s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	499
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	21
# Rejected: 	478
# Iteration: 	9 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	478
# Iteration: 	10 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	478
# Iteration: 	11 / 100
# Confirmed: 	18
# Tentative: 	3
# Rejected: 	478
# Iteration: 	12 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	13 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	14 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	15 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	16 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	17 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	18 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	19 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	20 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	21 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	22 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	23 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	24 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	25 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	26 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	27 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	28 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	29 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	30 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	31 / 100
# Confirmed: 	19
# Tentative: 	2
# Rejected: 	478
# Iteration: 	32 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	33 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	34 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	35 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	36 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	37 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	38 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	39 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	40 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	41 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	42 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	43 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	44 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	45 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	46 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	47 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	48 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	49 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	50 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	51 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	52 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	53 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	54 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	55 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	56 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	57 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	58 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	59 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	60 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	61 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	62 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	63 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	64 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	65 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	66 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	67 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	68 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	69 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	70 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	71 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	72 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	73 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	74 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	75 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	76 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	77 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	78 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	79 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	80 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	81 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	82 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	83 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	84 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	85 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	86 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	87 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	88 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	89 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	90 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	91 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	92 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	93 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	94 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	95 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	96 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	97 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	98 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
# Iteration: 	99 / 100
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	478
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	20
# Tentative: 	0
# Rejected: 	479
# BorutaPy(estimator=RandomForestClassifier(max_depth=7, n_estimators=92,
#                                           n_jobs=-1,
#                                           random_state=RandomState(MT19937) at 0x17FD59540),
#          n_estimators='auto', random_state=RandomState(MT19937) at 0x17FD59540,
#          verbose=2)

# %% [markdown]
# Borutaは有用な特徴量のみを選択しました。実行終了時、Borutaは2つの特徴量については決定できませんでした。
#
# `.support_` を調べることで、どの特徴量が選択されたかを確認できます。`.support_` はブール値の配列を返し、これを使って特徴量行列から関連するカラムのみを抽出できます。もちろん、scikit-learn APIに従い `.transform` を使うこともできます。

# %%
# Check selected features
print(feat_selector.support_)
# Select the chosen features from our dataframe.
selected = x.select(
    pl.nth([i for i, is_selected in enumerate(feat_selector.support_) if is_selected])
)
print()
print("Selected Feature Matrix Shape")
print(selected.shape)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#   True False False False False False False False False False False False
#  False False False False  True False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True False False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#   True False  True False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False  True False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False False False False  True False
#  False False False False False False False  True False  True False  True
#  False False False False False False False False False False False False
#  False False False False  True False False  True False False False False
#  False False False False False False False False False False False False
#  False  True False False False False False]
#
# Selected Feature Matrix Shape
# (2000, 20)

# %% [markdown]
# 選択されなかった特徴量のランキングも `.ranking_` で確認できます。

# %%
feat_selector.ranking_
# Out:
# array([426, 228, 266, 431,   7, 193, 254, 473, 347, 429,   3, 254, 121,
#         88, 165, 208, 301, 202,  71, 347, 337, 307, 390, 155, 189, 157,
#         95, 375,   1, 246, 414, 132,  59, 176, 349,  92, 256, 373,  25,
#        463, 452, 220, 101,  45,  40, 329, 213, 140,   1, 191, 239, 130,
#        342, 393, 188,  26,  20, 250, 441,  89, 294, 332, 351, 458,   1,
#        232, 215, 206, 144, 402, 285, 311, 309,  44, 204,  99, 448, 248,
#        179, 208, 321,  87, 356, 154, 128,  57, 444, 414, 218, 165, 480,
#        271, 323, 377, 421, 355, 437, 150, 244, 136, 405, 419, 428, 314,
#        173,   1,  92, 393, 374, 101, 358, 223, 416, 268, 210, 367,  30,
#        371, 186,  55, 459, 195, 287, 234, 369,  69, 181, 234,   1,  66,
#         61,  89, 297, 446, 161, 247,   9,  19, 439, 310,  55, 378, 398,
#        334, 340, 232, 412, 114, 420,  28, 362, 184,  52,   1, 462, 307,
#         64, 304, 117, 259, 229, 120, 409, 429, 126, 274, 471, 426, 470,
#        337, 315, 181, 184, 468, 334, 123, 369, 159, 296, 251,  78, 179,
#        152, 266,  37, 288, 315, 300,  66, 445, 133, 305, 108,  78, 227,
#        401, 190, 450, 476,  22, 289, 211,  50, 172,   2, 460, 155, 421,
#        302, 144, 371,  28, 376, 194, 358, 329, 403, 164, 159, 411, 124,
#        223, 259, 104,  54, 368,  47, 465, 478, 183, 423, 261, 343, 424,
#         51,  48, 293, 454, 100, 391, 276,   1, 399,  58,  22,  52, 173,
#        456, 195, 329,  95,  69, 451, 191, 440, 113, 126, 204, 391,  86,
#        244, 433, 257, 200, 112, 274, 207, 170, 163, 365, 215, 198, 115,
#        119, 333, 412, 475, 200,   7, 294, 461,   1,   4, 467, 105,  24,
#         18, 318, 449, 363, 128, 366, 379, 345, 147, 327,  17, 241,  32,
#        336, 168, 187, 386,  42, 285, 283, 138, 433, 324,  62,  41, 325,
#        297,  84, 213, 121, 399, 124,   1, 249, 321,  37, 325,  15, 408,
#        441, 344, 340, 317,  30, 135, 276, 466,  72,   5, 238,   1,  85,
#          1, 319, 103, 111, 271,  80, 406, 380, 382, 143,  12,  13, 443,
#        148, 171, 395, 146, 383, 361, 471,  95, 142, 236,  73, 161,  68,
#        424,  92, 240, 167, 353, 299,  49, 223, 281, 347,  60, 140, 446,
#         39,   1, 116, 432, 278,  97, 381,  33, 351, 291, 474, 282,  46,
#        453, 107, 457, 264, 455, 204, 386, 176, 289, 396, 435, 313, 463,
#        178, 479, 254,  42, 417, 268, 279,  15,  13,  28,  65,  62, 339,
#        396,  11, 306,  75, 353, 266, 237, 477,  21,  34, 291, 225, 117,
#        435,  37,   5,  77,   1, 263, 358,  80, 225,  98, 418, 386, 175,
#          1, 230, 152, 406, 274, 331, 110, 364, 283,   1, 279,   1, 149,
#          1, 259,  82, 230, 220, 134, 270, 157, 130, 358, 197, 217,  74,
#        151, 319, 242, 383,   1, 469, 388,   1, 351, 252,  75, 410, 200,
#          9, 404, 139, 137, 388, 312, 219, 213, 303, 105, 438, 109,   1,
#         35,  82, 244, 262, 169])
